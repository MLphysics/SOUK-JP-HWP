# %% [markdown]
# ## Characterising the Optical Axes of Sapphire Plates

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import SOUK_JP_HWP_ANALYSIS as hwp
from SOUK_JP_HWP_ANALYSIS import Gband, Fband

# %% [markdown]
# ## MF2 Test 16/01/26
#
# Test of procedure and code, MF2 had tape attached so the transmission will be affected.

# %%
hwp.main(
    pathref=Path.cwd()
    / "Data"
    / "GBand"
    / "20260116_D505mm-Alumina"
    / "Air-after-ppol-20260116-1_1000Hz_G_band_N_1001_20260116133606.npz",
    scan="MF2_rotation_test",
    material="sapphire_MF2",
    date="20260116",
    SUBFOLD="MLOG",
    title="MF2 Test 16/01",
    band=Gband
)

hwp.main(
    pathref=Path.cwd()
    / "Data"
    / "GBand"
    / "20260116_D505mm-Alumina"
    / "Air-after-ppol-20260116-1_1000Hz_G_band_N_1001_20260116133606.npz",
    scan="MF2_rotation_test",
    material="sapphire_MF2",
    date="20260116",
    SUBFOLD="detailed/MLOG",
    title="MF2 Test 16/01, detailed",
    band=Gband
)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 hwp.main(
#       2     pathref=Path.cwd()
#       3     / "Data"
#       4     / "GBand"
#       5     / "20260116_D505mm-Alumina"
#       6     / "Air-after-ppol-20260116-1_1000Hz_G_band_N_1001_20260116133606.npz",
#       7     scan="MF2_rotation_test",
#       8     material="sapphire_MF2",
#       9     date="20260116",
#      10     SUBFOLD="MLOG",
#      11     title="MF2 Test 16/01",
#      12     band=Gband
#      13 )
#      15 hwp.main(
#      16     pathref=Path.cwd()
#      17     / "Data"
#    (...)     26     band=Gband
#      27 )
#
# File c:\Users\w82312eh\OneDrive - The University of Manchester\Documents\SOUK-JP-HWP\SOUK-JP-HWP\SOUK_JP_HWP_ANALYSIS.py:265, in main(pathref, scan, material, date, SUBFOLD, title, band, INTERPPEAKS)
# ...
