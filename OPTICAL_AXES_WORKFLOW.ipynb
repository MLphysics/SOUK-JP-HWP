# %% [markdown]
# ## Characterising the Optical Axes of Sapphire Plates

# %%
import SOUK_JP_HWP_ANALYSIS as hwp
from SOUK_JP_HWP_ANALYSIS import Gband, Fband, TransScale

# %% [markdown]
# ## MF2 Test 16/01/26
#
# Test of procedure and code, MF2 had tape attached so the transmission will be affected.

# %%
hwp.main(
    scan="MF2_rotation_test",
    material="sapphire_MF2",
    date="20260116",
    SUBFOLD="MLOG",
    band=Gband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# # of points removed in trimming:  3
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (30.00°, -3.46 dB)  (125.00°, -2.59 dB)  (210.00°, -1.93 dB)  (295.00°, -1.99 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (28.00°, -3.46 dB)  (123.00°, -2.60 dB)  (210.00°, -1.94 dB)  (297.00°, -1.99 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF2 19/01/26

# %%
hwp.main(
    scan="MF2_3_rotation",
    material="sapphire_MF2",
    date="20260119",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# # of points removed in trimming:  3
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (35.00°, -2.57 dB)  (125.00°, -3.01 dB)  (215.00°, -2.54 dB)  (305.00°, -3.03 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (35.00°, -2.58 dB)  (126.00°, -3.02 dB)  (215.00°, -2.54 dB)  (305.00°, -3.03 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF3 Measurement 1 20/01/26

# %% [markdown]
# Centred (incomparable to 2,3,4).

# %%
hwp.main(
    scan="MF3_rotation",
    material="sapphire_MF3",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (60.00°, -3.21 dB)  (150.00°, -2.54 dB)  (240.00°, -2.92 dB)  (330.00°, -2.61 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (58.00°, -3.20 dB)  (148.00°, -2.53 dB)  (238.00°, -2.91 dB)  (328.00°, -2.60 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF3 Measurement 2 20/01/26

# %% [markdown]
# 50mm horizontal translation.

# %%
hwp.main(
    scan="MF3_rotation_50mmshift",
    material="sapphire_MF3",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (30.00°, -2.55 dB)  (120.00°, -2.97 dB)  (210.00°, -2.61 dB)  (300.00°, -3.02 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (29.00°, -2.54 dB)  (119.00°, -2.96 dB)  (208.00°, -2.59 dB)  (299.00°, -3.01 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF3 Measurement 3 20/01/26

# %% [markdown]
# Centred. Only detailed (5deg data copied from 5mm displacement).

# %%
hwp.main(
    scan="MF3_rotation_center",
    material="sapphire_MF3",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (30.00°, -2.55 dB)  (120.00°, -2.97 dB)  (210.00°, -2.61 dB)  (300.00°, -3.02 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (29.00°, -2.53 dB)  (118.00°, -2.91 dB)  (208.00°, -2.60 dB)  (299.00°, -3.20 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF3 Measurement 4 20/01/26

# %% [markdown]
# 100mm horizontal translation. Only detailed (5deg data copied from 5mm displacement).

# %%
hwp.main(
    scan="MF3_rotation_100mmshift",
    material="sapphire_MF3",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (30.00°, -2.55 dB)  (120.00°, -2.97 dB)  (210.00°, -2.61 dB)  (300.00°, -3.02 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (29.00°, -2.54 dB)  (119.00°, -2.99 dB)  (208.00°, -2.59 dB)  (298.00°, -3.04 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF4 20/01/26

# %%
hwp.main(
    scan="MF4_rotation",
    material="sapphire_MF4",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (90.00°, -2.63 dB)  (180.00°, -2.92 dB)  (270.00°, -2.59 dB)                    -
# 5° interp                   -                    -                    -                    -
# 1° raw      (0.00°, -2.97 dB)   (90.00°, -2.63 dB)  (180.00°, -2.92 dB)  (270.00°, -2.59 dB)
# 1° interp                   -                    -                    -                    -

# %% [markdown]
# ## MF1 20/01/26

# %%
hwp.main(
    scan="MF1_rotation",
    material="sapphire_MF1",
    date="20260120",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB, # change to TransScale.LINEAR if desired
    trimfunnydata=True, ## trims anythinglower that -4 dB
    ANNOTE_RAW=True, ## annotate the raw data ?
    ANNOTE_INTERP=False ## annotate the interpolations ?
)
# Out:
# Peak summary table:
#
#                        Peak 1               Peak 2               Peak 3               Peak 4
# 5° raw     (50.00°, -3.04 dB)  (140.00°, -2.57 dB)  (230.00°, -3.05 dB)  (320.00°, -2.53 dB)
# 5° interp                   -                    -                    -                    -
# 1° raw     (50.00°, -3.04 dB)  (140.00°, -2.57 dB)  (230.00°, -3.05 dB)  (320.00°, -2.53 dB)
# 1° interp                   -                    -                    -                    -
