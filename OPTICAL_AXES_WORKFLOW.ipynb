# %% [markdown]
# ## Characterising the Optical Axes of Sapphire Plates

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pathlib import Path
import SOUK_JP_HWP_ANALYSIS as hwp
from SOUK_JP_HWP_ANALYSIS import Gband, Fband, TransScale

# %% [markdown]
# ## MF2 Test 16/01/26
#
# Test of procedure and code, MF2 had tape attached so the transmission will be affected.

# %%
hwp.main(
    scan="MF2_rotation_test",
    material="sapphire_MF2",
    date="20260116",
    SUBFOLD="MLOG",
    band=Gband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB # change to TransScale.LINEAR if desired
)
# Out:
# c:\Users\w82312eh\OneDrive - The University of Manchester\Documents\SOUK-JP-HWP\SOUK-JP-HWP\Data\Gband\20260116_MF2_rotation_test

# %% [markdown]
# ## MF2 19/01/26

# %%
hwp.main(
    scan="MF2_3_rotation",
    material="sapphire_MF2",
    date="20260119",
    SUBFOLD="MLOG",
    band=Fband,
    INTERPPEAKS=False,
    TRANS_SCALE=TransScale.DB # change to TransScale.LINEAR if desired
)
# Out:
# c:\Users\w82312eh\OneDrive - The University of Manchester\Documents\SOUK-JP-HWP\SOUK-JP-HWP\Data\Fband\20260119_MF2_3_rotation
